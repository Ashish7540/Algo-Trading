#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# convert multi index to one touple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2015-01-02          24.565701        32.595486        177.463623
# 2015-01-05          23.873642        32.595486        174.258682
# 2015-01-06          23.875891        32.843018        172.617325
# 2015-01-07          24.210682        33.252995        174.768356
# 2015-01-08          25.140913        33.655201        177.869644
# ...                       ...              ...               ...
# 2023-02-13         153.850006        60.599998        412.829987
# 2023-02-14         153.199997        59.590000        412.640015
# 2023-02-15         155.330002        59.590000        413.980011
# 2023-02-16         153.710007        59.220001        408.279999
# 2023-02-17         152.550003        60.119999        407.260010
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2015-01-02      27.332500    42.139999    205.429993     27.860001
# ...

# %%
# convert the touple back to multi index
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2047.000000  2047.000000  2047.000000  2047.000000  2047.000000
# mean     72.426514    43.800625   282.686117    74.154255    49.076385
# std      49.848957     9.365390    88.035673    49.371617     6.929720
# min      20.883030    29.873718   161.225952    22.584999    37.560001
# 25%      29.482988    36.009266   204.040833    32.538750    43.490002
# 50%      47.317631    41.394249   261.420319    48.837502    46.570000
# 75%     124.608894    50.527706   366.490646   125.895000    54.230000
# max     180.683868    64.799706   470.083649   182.009995    66.209999
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2047.000000  2047.000000  2047.000000  2047.000000  2047.000000
# ...

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2015-01-02   27.332500  42.139999  205.429993
# 2015-01-05   26.562500  42.139999  201.720001
# 2015-01-06   26.565001  42.459999  199.820007
# 2015-01-07   26.937500  42.990002  202.309998
# 2015-01-08   27.972500  43.509998  205.899994
# ...                ...        ...         ...
# 2023-02-13  153.850006  60.599998  412.829987
# 2023-02-14  153.199997  59.590000  412.640015
# 2023-02-15  155.330002  59.590000  413.980011
# 2023-02-16  153.710007  59.220001  408.279999
# 2023-02-17  152.550003  60.119999  407.260010
#
# [2047 rows x 3 columns]

# %%
# to draw graphs
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot()
plt.legend()
plt.show()

# %%
# Simple Normalisation (value[i]/value[0]*100)
close.iloc[0]
# Out:
# AAPL     27.332500
# KO       42.139999
# SPY     205.429993
# Name: 2015-01-02 00:00:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#                   AAPL          KO         SPY
# Date
# 2015-01-02  100.000000  100.000000  100.000000
# 2015-01-05   97.182839  100.000000   98.194036
# 2015-01-06   97.191988  100.759373   97.269150
# 2015-01-07   98.554832  102.017091   98.481237
# 2015-01-08  102.341533  103.251065  100.228789
# ...                ...         ...         ...
# 2023-02-13  562.883028  143.806358  200.958965
# 2023-02-14  560.504873  141.409590  200.866489
# 2023-02-15  568.297811  141.409590  201.518778
# 2023-02-16  562.370819  140.531566  198.744104
# 2023-02-17  558.126774  142.667299  198.247590
#
# [2047 rows x 3 columns]

# %%
normclose.plot(figsize = (15,8))
plt.legend()
plt.show()

# %%
#Convert to a data frame
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   27.332500
# 2015-01-05   26.562500
# 2015-01-06   26.565001
# 2015-01-07   26.937500
# 2015-01-08   27.972500
# ...                ...
# 2023-02-13  153.850006
# 2023-02-14  153.199997
# 2023-02-15  155.330002
# 2023-02-16  153.710007
# 2023-02-17  152.550003
#
# [2047 rows x 1 columns]

# %%
aapl.shift()
# Out:
#                   AAPL
# Date
# 2015-01-02         NaN
# 2015-01-05   27.332500
# 2015-01-06   26.562500
# 2015-01-07   26.565001
# 2015-01-08   26.937500
# ...                ...
# 2023-02-13  151.009995
# 2023-02-14  153.850006
# 2023-02-15  153.199997
# 2023-02-16  155.330002
# 2023-02-17  153.710007
#
# [2047 rows x 1 columns]

# %%
#This step is done to calculate % change in daily closing value of the stock
aapl["lag1"] = aapl.shift()

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2015-01-02   27.332500         NaN
# 2015-01-05   26.562500   27.332500
# 2015-01-06   26.565001   26.562500
# 2015-01-07   26.937500   26.565001
# 2015-01-08   27.972500   26.937500
# ...                ...         ...
# 2023-02-13  153.850006  151.009995
# 2023-02-14  153.199997  153.850006
# 2023-02-15  155.330002  153.199997
# 2023-02-16  153.710007  155.330002
# 2023-02-17  152.550003  153.710007
#
# [2047 rows x 2 columns]

# %%
aapl["diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      diff
# Date
# 2015-01-02   27.332500         NaN       NaN
# 2015-01-05   26.562500   27.332500 -0.770000
# 2015-01-06   26.565001   26.562500  0.002501
# 2015-01-07   26.937500   26.565001  0.372499
# 2015-01-08   27.972500   26.937500  1.035000
# ...                ...         ...       ...
# 2023-02-13  153.850006  151.009995  2.840012
# 2023-02-14  153.199997  153.850006 -0.650009
# 2023-02-15  155.330002  153.199997  2.130005
# 2023-02-16  153.710007  155.330002 -1.619995
# 2023-02-17  152.550003  153.710007 -1.160004
#
# [2047 rows x 3 columns]

# %%
aapl["% change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      diff  % change
# Date
# 2015-01-02   27.332500         NaN       NaN       NaN
# 2015-01-05   26.562500   27.332500 -0.770000 -2.817161
# 2015-01-06   26.565001   26.562500  0.002501  0.009414
# 2015-01-07   26.937500   26.565001  0.372499  1.402219
# 2015-01-08   27.972500   26.937500  1.035000  3.842227
# ...                ...         ...       ...       ...
# 2023-02-13  153.850006  151.009995  2.840012  1.880678
# 2023-02-14  153.199997  153.850006 -0.650009 -0.422495
# 2023-02-15  155.330002  153.199997  2.130005  1.390343
# 2023-02-16  153.710007  155.330002 -1.619995 -1.042938
# 2023-02-17  152.550003  153.710007 -1.160004 -0.754670
#
# [2047 rows x 4 columns]

# %%
# delete unwanted columns
del aapl["lag1"]
del aapl["diff"]

# %%
aapl
# Out:
#                   AAPL  % change
# Date
# 2015-01-02   27.332500       NaN
# 2015-01-05   26.562500 -2.817161
# 2015-01-06   26.565001  0.009414
# 2015-01-07   26.937500  1.402219
# 2015-01-08   27.972500  3.842227
# ...                ...       ...
# 2023-02-13  153.850006  1.880678
# 2023-02-14  153.199997 -0.422495
# 2023-02-15  155.330002  1.390343
# 2023-02-16  153.710007 -1.042938
# 2023-02-17  152.550003 -0.754670
#
# [2047 rows x 2 columns]

# %%
aapl["% change2"] = aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL  % change  % change2
# Date
# 2015-01-02   27.332500       NaN        NaN
# 2015-01-05   26.562500 -2.817161  -2.817161
# 2015-01-06   26.565001  0.009414   0.009414
# 2015-01-07   26.937500  1.402219   1.402219
# 2015-01-08   27.972500  3.842227   3.842227
# ...                ...       ...        ...
# 2023-02-13  153.850006  1.880678   1.880678
# 2023-02-14  153.199997 -0.422495  -0.422495
# 2023-02-15  155.330002  1.390343   1.390343
# 2023-02-16  153.710007 -1.042938  -1.042938
# 2023-02-17  152.550003 -0.754670  -0.754670
#
# [2047 rows x 3 columns]

# %%
#aapl["%change3"] = aapl.AAPL.sub(aapl.lag1).div(aapl.AAPL).mul(100)
#aapl

# %%
# delete unwanted columns
del aapl["% change2"]
aapl
# Out:
#                   AAPL  % change
# Date
# 2015-01-02   27.332500       NaN
# 2015-01-05   26.562500 -2.817161
# 2015-01-06   26.565001  0.009414
# 2015-01-07   26.937500  1.402219
# 2015-01-08   27.972500  3.842227
# ...                ...       ...
# 2023-02-13  153.850006  1.880678
# 2023-02-14  153.199997 -0.422495
# 2023-02-15  155.330002  1.390343
# 2023-02-16  153.710007 -1.042938
# 2023-02-17  152.550003 -0.754670
#
# [2047 rows x 2 columns]

# %%
del aapl["% change"]
aapl
# Out:
#                   AAPL
# Date
# 2015-01-02   27.332500
# 2015-01-05   26.562500
# 2015-01-06   26.565001
# 2015-01-07   26.937500
# 2015-01-08   27.972500
# ...                ...
# 2023-02-13  153.850006
# 2023-02-14  153.199997
# 2023-02-15  155.330002
# 2023-02-16  153.710007
# 2023-02-17  152.550003
#
# [2047 rows x 1 columns]

# %%
aapl.AAPL.resample("BM").last()
# Out:
# Date
# 2015-01-30     29.290001
# 2015-02-27     32.115002
# 2015-03-31     31.107500
# 2015-04-30     31.287500
# 2015-05-29     32.570000
#                  ...
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-30    129.929993
# 2023-01-31    144.289993
# 2023-02-28    152.550003
# Freq: BM, Name: AAPL, Length: 98, dtype: float64

# %%
aapl.AAPL.resample("BM").last()
# Out:
# Date
# 2015-01-30     29.290001
# 2015-02-27     32.115002
# 2015-03-31     31.107500
# 2015-04-30     31.287500
# 2015-05-29     32.570000
#                  ...
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-30    129.929993
# 2023-01-31    144.289993
# 2023-02-28    152.550003
# Freq: BM, Name: AAPL, Length: 98, dtype: float64

# %%
ret=aapl.pct_change(periods=1).dropna()
ret
# Out:
#                 AAPL
# Date
# 2015-01-05 -0.028172
# 2015-01-06  0.000094
# 2015-01-07  0.014022
# 2015-01-08  0.038422
# 2015-01-09  0.001073
# ...              ...
# 2023-02-13  0.018807
# 2023-02-14 -0.004225
# 2023-02-15  0.013903
# 2023-02-16 -0.010429
# 2023-02-17 -0.007547
#
# [2046 rows x 1 columns]

# %%
ret.plot(kind="hist", figsize=(15,8), bins=100)
plt.show()

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001018
# dtype: float64

# %%
daily_var = ret.var()
daily_var
# Out:
# AAPL    0.000355
# dtype: float64

# %%
daily_sd = ret.std()
daily_sd
# Out:
# AAPL    0.018841
# dtype: float64

# %%
annual_mean_ret = daily_mean_ret.mul(252)   # there are 252 business days in an year
annual_mean_ret
# Out:
# AAPL    0.256594
# dtype: float64

# %%
annual_var_ret = daily_var.mul(252)
annual_var_ret
# Out:
# AAPL    0.089454
# dtype: float64

# %%
annual_sd_ret = np.sqrt(annual_var_ret)
annual_sd_ret
# Out:
# AAPL    0.299089
# dtype: float64

# %%
# Comparing multiple stocks with Bitcoin (risk/return curve)
ticker = ["AAPL", "MSFT", "DIS", "AMZN", "UBER", "BTC-USD"]

# %%
Stocks = yf.download(ticker, start = "2013-01-01", end = "2023-02-21").dropna()
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
Stocks
# Out:
#              Adj Close                                                    \
#                   AAPL        AMZN       BTC-USD         DIS        MSFT
# Date
# 2019-05-10   47.893280   94.499001   6378.849121  132.421646  122.007248
# 2019-05-13   45.109745   91.134003   7814.915039  129.754242  118.379585
# 2019-05-14   45.823849   92.005997   7994.416016  131.591782  119.703995
# 2019-05-15   46.372780   93.557503   8205.167969  133.053925  121.389671
# 2019-05-16   46.168751   95.378502   7884.909180  133.864029  124.192764
# ...                ...         ...           ...         ...         ...
# 2023-02-13  153.850006   99.540001  21808.101562  107.660004  270.642120
# 2023-02-14  153.199997   99.699997  22220.804688  107.660004  271.490021
# 2023-02-15  155.330002  101.160004  24307.841797  109.239998  269.320007
# 2023-02-16  153.710007   98.150002  23623.474609  105.830002  262.149994
# 2023-02-17  152.550003   97.199997  24565.601562  105.220001  258.059998
#
# ...

# %%
Stocks.to_csv("BTC_vs_stocks.csv")
stocks = pd.read_csv("BTC_vs_stocks.csv", header = [0,1], index_col=[0], parse_dates=[0])

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL        AMZN       BTC-USD         DIS        MSFT  \
# Date
# 2019-05-10   49.294998   94.499001   6378.849121  134.039993  127.129997
# 2019-05-13   46.430000   91.134003   7814.915039  131.339996  123.349998
# 2019-05-14   47.165001   92.005997   7994.416016  133.199997  124.730003
# 2019-05-15   47.730000   93.557503   8205.167969  134.679993  126.019997
# 2019-05-16   47.520000   95.378502   7884.909180  135.500000  128.929993
# ...                ...         ...           ...         ...         ...
# 2023-02-13  153.850006   99.540001  21808.101562  107.660004  271.320007
# 2023-02-14  153.199997   99.699997  22220.804688  107.660004  272.170013
# 2023-02-15  155.330002  101.160004  24307.841797  109.239998  269.320007
# 2023-02-16  153.710007   98.150002  23623.474609  105.830002  262.149994
# 2023-02-17  152.550003   97.199997  24565.601562  105.220001  258.059998
#
#                  UBER
# Date
# 2019-05-10  41.570000
# 2019-05-13  37.099998
# ...

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#                   AAPL        AMZN     BTC-USD         DIS        MSFT  \
# Date
# 2019-05-10  100.000000  100.000000  100.000000  100.000000  100.000000
# 2019-05-13   94.188056   96.439118  122.512931   97.985678   97.026667
# 2019-05-14   95.679080   97.361873  125.326934   99.373324   98.112173
# 2019-05-15   96.825238   99.003695  128.630852  100.477469   99.126877
# 2019-05-16   96.399234  100.930699  123.610216  101.089232  101.415870
# ...                ...         ...         ...         ...         ...
# 2023-02-13  312.100643  105.334448  341.881445   80.319314  213.419345
# 2023-02-14  310.782032  105.503758  348.351313   80.319314  214.087957
# 2023-02-15  315.102967  107.048755  381.069396   81.498063  211.846152
# 2023-02-16  311.816639  103.863534  370.340702   78.954049  206.206245
# 2023-02-17  309.463452  102.858227  385.110246   78.498960  202.989069
#
#                   UBER
# Date
# 2019-05-10  100.000000
# 2019-05-13   89.247050
# 2019-05-14   96.127013
# ...

# %%
normclose.plot(figsize = (15,8))
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL      AMZN   BTC-USD       DIS      MSFT      UBER
# Date
# 2019-05-13 -0.058119 -0.035609  0.225129 -0.020143 -0.029733 -0.107529
# 2019-05-14  0.015830  0.009568  0.022969  0.014162  0.011188  0.077089
# 2019-05-15  0.011979  0.016863  0.026362  0.011111  0.010342  0.033283
# 2019-05-16 -0.004400  0.019464 -0.039031  0.006089  0.023092  0.041414
# 2019-05-17 -0.005682 -0.020219 -0.068614 -0.003395 -0.006670 -0.025349

# %%
ret.describe()
# Out:
#              AAPL        AMZN     BTC-USD         DIS        MSFT        UBER
# count  951.000000  951.000000  951.000000  951.000000  951.000000  951.000000
# mean     0.001428    0.000299    0.002486   -0.000003    0.000956    0.000507
# std      0.021881    0.023212    0.045696    0.022459    0.020532    0.037697
# min     -0.128647   -0.140494   -0.371695   -0.131632   -0.147390   -0.216288
# 25%     -0.009300   -0.011518   -0.017881   -0.010980   -0.009125   -0.020338
# 50%      0.001097    0.000719    0.000413   -0.000427    0.000913   -0.000574
# 75%      0.013642    0.011689    0.022993    0.009973    0.011179    0.020133
# max      0.119808    0.135359    0.225129    0.144123    0.142169    0.382591

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# AAPL     951.0  0.001428  0.021881 -0.128647 -0.009300  0.001097  0.013642
# AMZN     951.0  0.000299  0.023212 -0.140494 -0.011518  0.000719  0.011689
# BTC-USD  951.0  0.002486  0.045696 -0.371695 -0.017881  0.000413  0.022993
# DIS      951.0 -0.000003  0.022459 -0.131632 -0.010980 -0.000427  0.009973
# MSFT     951.0  0.000956  0.020532 -0.147390 -0.009125  0.000913  0.011179
# UBER     951.0  0.000507  0.037697 -0.216288 -0.020338 -0.000574  0.020133
#
#               max
# AAPL     0.119808
# AMZN     0.135359
# BTC-USD  0.225129
# DIS      0.144123
# MSFT     0.142169
# UBER     0.382591

# %%
summary=ret.describe().T.loc[:, ["mean", "std"]]

# %%
summary
# Out:
#              mean       std
# AAPL     0.001428  0.021881
# AMZN     0.000299  0.023212
# BTC-USD  0.002486  0.045696
# DIS     -0.000003  0.022459
# MSFT     0.000956  0.020532
# UBER     0.000507  0.037697

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#              mean       std
# AAPL     0.359784  0.347353
# AMZN     0.075299  0.368478
# BTC-USD  0.626398  0.725397
# DIS     -0.000816  0.356532
# MSFT     0.240806  0.325935
# UBER     0.127830  0.598417

# %%
summary.plot.scatter(x="std", y="mean", figsize = (15,8), s=50, fontsize=15)
# Out:
# <AxesSubplot:xlabel='std', ylabel='mean'>

# %%
summary.plot.scatter(x="std", y="mean", figsize = (12,6), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]-0.02))
plt.xlabel("Annual risk(std)", fontsize=15)
plt.ylabel("Annual return(mean)", fontsize=15)
plt.title("Risk vs Return", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk vs Return')

# %%
ret
# Out:
#                 AAPL      AMZN   BTC-USD       DIS      MSFT      UBER
# Date
# 2019-05-13 -0.058119 -0.035609  0.225129 -0.020143 -0.029733 -0.107529
# 2019-05-14  0.015830  0.009568  0.022969  0.014162  0.011188  0.077089
# 2019-05-15  0.011979  0.016863  0.026362  0.011111  0.010342  0.033283
# 2019-05-16 -0.004400  0.019464 -0.039031  0.006089  0.023092  0.041414
# 2019-05-17 -0.005682 -0.020219 -0.068614 -0.003395 -0.006670 -0.025349
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-13  0.018807  0.019773  0.007248 -0.003702  0.031243 -0.025073
# 2023-02-14 -0.004225  0.001607  0.018924  0.000000  0.003133  0.053529
# 2023-02-15  0.013903  0.014644  0.093923  0.014676 -0.010471  0.028385
# 2023-02-16 -0.010429 -0.029755 -0.028154 -0.031216 -0.026623 -0.000276
# 2023-02-17 -0.007547 -0.009679  0.039881 -0.005764 -0.015602 -0.040033
#
# [951 rows x 6 columns]

# %% [markdown]
# # Covariance and Corelation

# %%
#Covariance of the stocks
ret.cov()
# Out:
#              AAPL      AMZN   BTC-USD       DIS      MSFT      UBER
# AAPL     0.000479  0.000329  0.000260  0.000245  0.000355  0.000310
# AMZN     0.000329  0.000539  0.000295  0.000238  0.000336  0.000364
# BTC-USD  0.000260  0.000295  0.002088  0.000308  0.000285  0.000413
# DIS      0.000245  0.000238  0.000308  0.000504  0.000248  0.000406
# MSFT     0.000355  0.000336  0.000285  0.000248  0.000422  0.000317
# UBER     0.000310  0.000364  0.000413  0.000406  0.000317  0.001421

# %%
#Co-relation b/w the stocks
ret.corr()
# Out:
#              AAPL      AMZN   BTC-USD       DIS      MSFT      UBER
# AAPL     1.000000  0.647216  0.259545  0.497526  0.789842  0.375303
# AMZN     0.647216  1.000000  0.277875  0.455571  0.704605  0.416054
# BTC-USD  0.259545  0.277875  1.000000  0.299918  0.303975  0.239874
# DIS      0.497526  0.455571  0.299918  1.000000  0.537371  0.479491
# MSFT     0.789842  0.704605  0.303975  0.537371  1.000000  0.409477
# UBER     0.375303  0.416054  0.239874  0.479491  0.409477  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(ret.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Returns and Log returns

# %%
# Creating sample dataframe
df=pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 95], columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
# Calculate Simple interest and mean of simple interest
simple_returns=df.pct_change().dropna()
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
# Try to find out final value using simple returns
Vf = 100*1.2*1.2
Vf      #Note that final value do not match with data frame final value
# So we need log returns here
# Out:
# 144.0

# %%
#Finding lof returns and mean log returns
log_returns=np.log(df/df.shift(1)).dropna()
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
# Now finding final value using log returns
Vf = 100*np.exp(log_returns.mean()*2)
Vf
# Note here we got correct final value
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
SPY
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.218224
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.397594
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.451387
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.720428
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.828053
# ...                ...         ...         ...         ...         ...
# 2023-02-17  406.059998  407.510010  404.049988  407.260010  407.260010
# 2023-02-21  403.059998  404.160004  398.820007  399.089996  399.089996
# 2023-02-22  399.519989  401.130005  397.019989  398.540009  398.540009
# 2023-02-23  401.559998  402.200012  396.250000  400.660004  400.660004
# 2023-02-24  395.420013  397.250000  393.640015  396.380005  396.380005
#
#                Volume
# Date
# ...

# %%
spy = SPY.Close.to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-02-17  407.260010
# 2023-02-21  399.089996
# 2023-02-22  398.540009
# 2023-02-23  400.660004
# 2023-02-24  396.380005
#
# [7573 rows x 1 columns]

# %%
spy.plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Used to find rooling operations for the window period (like mean, median, mode, max, min....)
spy_roll=spy.rolling(window=10)
spy_roll
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
#Mean of past 10 days
spy_roll_mean = spy_roll.mean()
spy_roll_mean
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-02-17  410.579001
# 2023-02-21  409.505002
# 2023-02-22  407.840002
# 2023-02-23  406.841003
# 2023-02-24  405.770004
#
# [7573 rows x 1 columns]

# %%
spy_roll_median=spy_roll.median()
spy_roll_median
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-02-17  410.239990
# 2023-02-21  409.464996
# 2023-02-22  408.160004
# 2023-02-23  407.650009
# 2023-02-24  407.650009
#
# [7573 rows x 1 columns]

# %%
# min_periods attribute finds the rolling value starting from the min period row, but as we pass window period, it will be counting window period only
spy.rolling(window=10, min_periods=5).mean().head(20)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04  44.468750
# 1993-02-05  44.552083
# 1993-02-08  44.611607
# 1993-02-09  44.617188
# 1993-02-10  44.628472
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875
# 1993-02-22  44.146875
# 1993-02-23  44.018750
# 1993-02-24  43.978125
# 1993-02-25  43.940625
# 1993-02-26  43.887500

# %%
spy.rolling(window=10).mean().head(20)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875
# 1993-02-22  44.146875
# 1993-02-23  44.018750
# 1993-02-24  43.978125
# 1993-02-25  43.940625
# 1993-02-26  43.887500

# %%
spy["SMA50"]=spy.rolling(window=50).mean()

# %%
spy
# Out:
#                  Close     SMA50
# Date
# 1993-01-29   43.937500       NaN
# 1993-02-01   44.250000       NaN
# 1993-02-02   44.343750       NaN
# 1993-02-03   44.812500       NaN
# 1993-02-04   45.000000       NaN
# ...                ...       ...
# 2023-02-17  407.260010  396.5978
# 2023-02-21  399.089996  396.7164
# 2023-02-22  398.540009  396.7624
# 2023-02-23  400.660004  396.9100
# 2023-02-24  396.380005  396.8586
#
# [7573 rows x 2 columns]

# %%
spy.plot(figsize=(15,8), fontsize=15)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Here we need to specify spy.Close because now we have 2 columns
spy["SMA200"]=spy.Close.rolling(window=200).mean()

# %%
spy
# Out:
#                  Close     SMA50     SMA200
# Date
# 1993-01-29   43.937500       NaN        NaN
# 1993-02-01   44.250000       NaN        NaN
# 1993-02-02   44.343750       NaN        NaN
# 1993-02-03   44.812500       NaN        NaN
# 1993-02-04   45.000000       NaN        NaN
# ...                ...       ...        ...
# 2023-02-17  407.260010  396.5978  393.40895
# 2023-02-21  399.089996  396.7164  393.25910
# 2023-02-22  398.540009  396.7624  393.18275
# 2023-02-23  400.660004  396.9100  393.12935
# 2023-02-24  396.380005  396.8586  393.12040
#
# [7573 rows x 3 columns]

# %%
spy.plot(figsize=(15,8), fontsize=15)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# plotting Exponential moving avg (EMA100)
spy["EMA100"]=spy.Close.ewm(span=100).mean()
spy.plot(figsize=(15,8), fontsize=15)
# Out:
# <AxesSubplot:xlabel='Date'>
